# %%
from pgmpy.models import BayesianModel

# %%
cancer_model = BayesianModel([('Pollution','Cancer'),('Smoker', 'Cancer'),('Cancer', 'Xray'),('Cancer','Dyspnoea')])
cancer_model.nodes() 
cancer_model.edges() 
cancer_model.get_cpds()
# Out:
# []

# %%
from pgmpy.factors.discrete import TabularCPD 
 
cpd_poll = TabularCPD(variable='Pollution', variable_card=2,
                      values=[[0.9], [0.1]]) 
cpd_smoke = TabularCPD(variable='Smoker', variable_card=2,
                       values=[[0.3], [0.7]]) 
cpd_cancer = TabularCPD(variable='Cancer', variable_card=2,
                        values=[[0.03, 0.05, 0.001, 0.02],[0.97, 0.95, 0.999, 0.98]],    
                        evidence=['Smoker', 'Pollution'],
                        evidence_card=[2, 2]) 
cpd_xray = TabularCPD(variable='Xray', variable_card=2,
                      values=[[0.9, 0.2], [0.1, 0.8]],
                      evidence=['Cancer'], evidence_card=[2]) 
cpd_dysp = TabularCPD(variable='Dyspnoea', variable_card=2,
                      values=[[0.65, 0.3], [0.35, 0.7]],
                      evidence=['Cancer'], evidence_card=[2])

# %%
# Associating Conditional probabilities with the Bayesian Structure 
# Associating the parameters with the model structure. 
cancer_model.add_cpds(cpd_poll, cpd_smoke, cpd_cancer, cpd_xray, cpd_dysp) 
# Checking if the cpds are valid for the model. 
cancer_model.check_model()
# Out:
# True

# %%
# Doing some simple queries on the network 
print(cancer_model.active_trail_nodes('Pollution', 'Smoker')) 
print(cancer_model.active_trail_nodes(['Pollution', 'Smoker'], observed=['Cancer']))
cancer_model.get_cpds()
# Out:
# {'Pollution': {'Pollution', 'Xray', 'Cancer', 'Dyspnoea'}}
# {'Pollution': {'Pollution', 'Smoker'}, 'Smoker': {'Pollution', 'Smoker'}}
# [<TabularCPD representing P(Pollution:2) at 0x7fd6688746a0>,
#  <TabularCPD representing P(Smoker:2) at 0x7fd6688b9ba8>,
#  <TabularCPD representing P(Cancer:2 | Smoker:2, Pollution:2) at 0x7fd668866be0>,
#  <TabularCPD representing P(Xray:2 | Cancer:2) at 0x7fd6688b9be0>,
#  <TabularCPD representing P(Dyspnoea:2 | Cancer:2) at 0x7fd6688b96a0>]

# %%
#print the conditional probability table of each node(variable) of the bayesian network model
print(cancer_model.get_cpds('Pollution'))
print(cancer_model.get_cpds('Smoker')) 
print(cancer_model.get_cpds('Xray')) 
print(cancer_model.get_cpds('Dyspnoea')) 
print(cancer_model.get_cpds('Cancer'))
# Out:
# +-------------+-----+
# | Pollution_0 | 0.9 |
# +-------------+-----+
# | Pollution_1 | 0.1 |
# +-------------+-----+
# +----------+-----+
# | Smoker_0 | 0.3 |
# +----------+-----+
# | Smoker_1 | 0.7 |
# +----------+-----+
# +--------+----------+----------+
# | Cancer | Cancer_0 | Cancer_1 |
# +--------+----------+----------+
# | Xray_0 | 0.9      | 0.2      |
# +--------+----------+----------+
# | Xray_1 | 0.1      | 0.8      |
# +--------+----------+----------+
# +------------+----------+----------+
# | Cancer     | Cancer_0 | Cancer_1 |
# +------------+----------+----------+
# | Dyspnoea_0 | 0.65     | 0.3      |
# +------------+----------+----------+
# | Dyspnoea_1 | 0.35     | 0.7      |
# +------------+----------+----------+
# +-----------+-------------+-------------+-------------+-------------+
# | Smoker    | Smoker_0    | Smoker_0    | Smoker_1    | Smoker_1    |
# +-----------+-------------+-------------+-------------+-------------+
# | Pollution | Pollution_0 | Pollution_1 | Pollution_0 | Pollution_1 |
# +-----------+-------------+-------------+-------------+-------------+
# | Cancer_0  | 0.03        | 0.05        | 0.001       | 0.02        |
# +-----------+-------------+-------------+-------------+-------------+
# | Cancer_1  | 0.97        | 0.95        | 0.999       | 0.98        |
# +-----------+-------------+-------------+-------------+-------------+

# %%
# Determining the Local independencies of each node
cancer_model.local_independencies('Xray') 
cancer_model.local_independencies('Pollution') 
cancer_model.local_independencies('Smoker') 
cancer_model.local_independencies('Dyspnoea') 
cancer_model.local_independencies('Cancer')
cancer_model.get_independencies()
# Out:
# (Pollution _|_ Smoker)
# (Pollution _|_ Xray, Dyspnoea | Cancer)
# (Pollution _|_ Dyspnoea | Xray, Cancer)
# (Pollution _|_ Xray, Dyspnoea | Cancer, Smoker)
# (Pollution _|_ Xray | Cancer, Dyspnoea)
# (Pollution _|_ Dyspnoea | Xray, Cancer, Smoker)
# (Pollution _|_ Xray | Dyspnoea, Cancer, Smoker)
# (Smoker _|_ Pollution)
# (Smoker _|_ Xray, Dyspnoea | Cancer)
# (Smoker _|_ Xray, Dyspnoea | Pollution, Cancer)
# (Smoker _|_ Dyspnoea | Xray, Cancer)
# (Smoker _|_ Xray | Cancer, Dyspnoea)
# (Smoker _|_ Dyspnoea | Pollution, Xray, Cancer)
# (Smoker _|_ Xray | Pollution, Cancer, Dyspnoea)
# (Xray _|_ Pollution, Smoker, Dyspnoea | Cancer)
# (Xray _|_ Smoker, Dyspnoea | Pollution, Cancer)
# (Xray _|_ Pollution, Dyspnoea | Cancer, Smoker)
# (Xray _|_ Pollution, Smoker | Cancer, Dyspnoea)
# (Xray _|_ Dyspnoea | Pollution, Cancer, Smoker)
# (Xray _|_ Smoker | Pollution, Cancer, Dyspnoea)
# (Xray _|_ Pollution | Dyspnoea, Cancer, Smoker)
# (Dyspnoea _|_ Pollution, Xray, Smoker | Cancer)
# (Dyspnoea _|_ Xray, Smoker | Pollution, Cancer)
# (Dyspnoea _|_ Pollution, Smoker | Xray, Cancer)
# (Dyspnoea _|_ Pollution, Xray | Cancer, Smoker)
# (Dyspnoea _|_ Smoker | Pollution, Xray, Cancer)
# (Dyspnoea _|_ Xray | Pollution, Cancer, Smoker)
# (Dyspnoea _|_ Pollution | Xray, Cancer, Smoker)

# %%
#.Inferencing with Bayesian Network 
# Doing exact inference using Variable Elimination 
from pgmpy.inference import VariableElimination 
cancer_infer = VariableElimination(cancer_model) 
 
# Computing the probability of bronc given smoke. 
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1}) 
print(q['Cancer']) 

# Computing the probability of bronc given smoke. 
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1,'Pollution': 1}) 
print(q['Cancer'])
# Out:
# +----------+---------------+
# | Cancer   |   phi(Cancer) |
# +==========+===============+
# | Cancer_0 |        0.0029 |
# +----------+---------------+
# | Cancer_1 |        0.9971 |
# +----------+---------------+
# +----------+---------------+
# | Cancer   |   phi(Cancer) |
# +==========+===============+
# | Cancer_0 |        0.0029 |
# +----------+---------------+
# | Cancer_1 |        0.9971 |
# +----------+---------------+
# +----------+---------------+
# | Cancer   |   phi(Cancer) |
# +==========+===============+
# | Cancer_0 |        0.0200 |
# +----------+---------------+
# | Cancer_1 |        0.9800 |
# +----------+---------------+
# /usr/local/lib/python3.6/dist-packages/pgmpy/factors/discrete/DiscreteFactor.py:586: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi.values = phi.values[slice_]

# %%
#Diagnosis of heart patients using standard Heart Disease Data Set 
import numpy as np 
from urllib.request import urlopen 
import pandas as pd

# %%
#Importing Heart Disease Data Set and Customizing 
Cleveland_data_URL ='http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'

# %%
#np.set_printoptions(threshold=np.nan)
np.set_printoptions()
names = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','heartdisease'] 
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names) 
heartDisease.head() 
del heartDisease['ca'] 
del heartDisease['slope'] 
del heartDisease['thal'] 
del heartDisease['oldpeak'] 
 
heartDisease = heartDisease.replace('?', np.nan) 
heartDisease.dtypes 
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
#Modeling Heart Disease Data 
from pgmpy.models import BayesianModel 
from pgmpy.estimators import MaximumLikelihoodEstimator
model = BayesianModel([('age','trestbps'),('age','fbs'),('sex','trestbps'), 
                       ('sex','trestbps'),('exang', 'trestbps'),('trestbps','heartdisease'),( 'fbs','heartdisease'),
                       ('heartdisease','restecg'),('heartdisease','thalach' ),('heartdisease','chol')])

# %%
# Learing CPDs using Maximum Likelihood Estimators 
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
print(model.get_cpds('age')) 
print(model.get_cpds('chol')) 
print(model.get_cpds('sex')) 
model.get_independencies()
# Out:
# +---------+------------+
# | age(28) | 0.00383142 |
# +---------+------------+
# | age(29) | 0.00383142 |
# +---------+------------+
# | age(30) | 0.00383142 |
# +---------+------------+
# | age(31) | 0.00766284 |
# +---------+------------+
# | age(32) | 0.0153257  |
# +---------+------------+
# | age(33) | 0.00766284 |
# +---------+------------+
# | age(34) | 0.0153257  |
# +---------+------------+
# | age(35) | 0.0191571  |
# +---------+------------+
# | age(36) | 0.0191571  |
# +---------+------------+
# | age(37) | 0.0306513  |
# +---------+------------+
# | age(38) | 0.0191571  |
# +---------+------------+
# | age(39) | 0.0344828  |
# +---------+------------+
# | age(40) | 0.0191571  |
# +---------+------------+
# | age(41) | 0.0383142  |
# +---------+------------+
# | age(42) | 0.0268199  |
# +---------+------------+
# | age(43) | 0.0421456  |
# +---------+------------+
# | age(44) | 0.0268199  |
# +---------+------------+
# | age(45) | 0.0229885  |
# +---------+------------+
# | age(46) | 0.045977   |
# +---------+------------+
# | age(47) | 0.0344828  |
# +---------+------------+
# | age(48) | 0.0613027  |
# +---------+------------+
# | age(49) | 0.0421456  |
# +---------+------------+
# | age(50) | 0.045977   |
# +---------+------------+
# | age(51) | 0.0344828  |
# +---------+------------+
# | age(52) | 0.0574713  |
# +---------+------------+
# | age(53) | 0.0383142  |
# +---------+------------+
# | age(54) | 0.0842912  |
# +---------+------------+
# | age(55) | 0.0536398  |
# +---------+------------+
# | age(56) | 0.0306513  |
# +---------+------------+
# | age(57) | 0.0191571  |
# +---------+------------+
# | age(58) | 0.0344828  |
# +---------+------------+
# | age(59) | 0.0229885  |
# +---------+------------+
# | age(60) | 0.00766284 |
# +---------+------------+
# | age(61) | 0.00766284 |
# +---------+------------+
# | age(62) | 0.00766284 |
# +---------+------------+
# | age(63) | 0.00383142 |
# +---------+------------+
# | age(65) | 0.0114943  |
# +---------+------------+
# | age(66) | 0          |
# +---------+------------+
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(100)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(117)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(129)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(132)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(147)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(156)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(161)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(163)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(171)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(173)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(179)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(190)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(194)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(202)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.024539877300613498 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(238)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.012269938650306749 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(251)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.006134969325153374 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(272)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(279)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(280)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(285)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(287)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(291)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(292)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(297)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(312)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(320)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(328)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(329)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(331)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(336)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(338)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(339)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(344)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(347)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(355)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(358)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(365)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(388)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(392)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(393)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(404)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(412)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(466)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(468)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(491)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(518)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(529)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(603)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(85)     | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# +--------+----------+
# | sex(0) | 0.264368 |
# +--------+----------+
# | sex(1) | 0.735632 |
# +--------+----------+
# (age _|_ sex, exang)
# (age _|_ exang | sex)
# (age _|_ sex | exang)
# (age _|_ sex, exang | fbs)
# (age _|_ thalach, chol, restecg | heartdisease)
# (age _|_ exang | fbs, sex)
# (age _|_ thalach, chol, restecg | sex, heartdisease)
# (age _|_ sex | fbs, exang)
# (age _|_ thalach, chol, restecg | exang, heartdisease)
# (age _|_ thalach, chol | restecg, heartdisease)
# (age _|_ thalach, restecg | chol, heartdisease)
# (age _|_ chol, restecg | thalach, heartdisease)
# (age _|_ thalach, chol, restecg, heartdisease | fbs, trestbps)
# (age _|_ thalach, chol, restecg | fbs, heartdisease)
# (age _|_ thalach, chol, restecg | trestbps, heartdisease)
# (age _|_ thalach, chol, restecg | sex, exang, heartdisease)
# (age _|_ thalach, chol | sex, restecg, heartdisease)
# (age _|_ thalach, restecg | chol, sex, heartdisease)
# (age _|_ chol, restecg | thalach, sex, heartdisease)
# (age _|_ thalach, chol, restecg, heartdisease | trestbps, fbs, sex)
# (age _|_ thalach, chol, restecg | fbs, sex, heartdisease)
# (age _|_ thalach, chol, restecg | trestbps, sex, heartdisease)
# (age _|_ thalach, chol | exang, restecg, heartdisease)
# (age _|_ thalach, restecg | chol, exang, heartdisease)
# (age _|_ chol, restecg | thalach, exang, heartdisease)
# (age _|_ thalach, chol, restecg, heartdisease | fbs, trestbps, exang)
# (age _|_ thalach, chol, restecg | fbs, exang, heartdisease)
# (age _|_ thalach, chol, restecg | trestbps, exang, heartdisease)
# (age _|_ thalach | chol, restecg, heartdisease)
# (age _|_ chol | thalach, restecg, heartdisease)
# (age _|_ thalach, chol, heartdisease | fbs, trestbps, restecg)
# (age _|_ thalach, chol | fbs, restecg, heartdisease)
# (age _|_ thalach, chol | trestbps, restecg, heartdisease)
# (age _|_ restecg | thalach, chol, heartdisease)
# (age _|_ thalach, restecg, heartdisease | trestbps, fbs, chol)
# (age _|_ thalach, restecg | fbs, chol, heartdisease)
# (age _|_ thalach, restecg | trestbps, chol, heartdisease)
# (age _|_ chol, restecg, heartdisease | thalach, fbs, trestbps)
# (age _|_ chol, restecg | thalach, fbs, heartdisease)
# (age _|_ chol, restecg | thalach, trestbps, heartdisease)
# (age _|_ thalach, chol, restecg | fbs, trestbps, heartdisease)
# (age _|_ thalach, chol | sex, exang, restecg, heartdisease)
# (age _|_ thalach, restecg | chol, sex, exang, heartdisease)
# (age _|_ chol, restecg | thalach, sex, exang, heartdisease)
# (age _|_ thalach, chol, restecg, heartdisease | trestbps, fbs, sex, exang)
# (age _|_ thalach, chol, restecg | fbs, sex, exang, heartdisease)
# (age _|_ thalach, chol, restecg | trestbps, sex, exang, heartdisease)
# (age _|_ thalach | chol, sex, restecg, heartdisease)
# (age _|_ chol | thalach, sex, restecg, heartdisease)
# (age _|_ thalach, chol, heartdisease | trestbps, fbs, sex, restecg)
# (age _|_ thalach, chol | fbs, sex, restecg, heartdisease)
# (age _|_ thalach, chol | trestbps, sex, restecg, heartdisease)
# (age _|_ restecg | chol, thalach, sex, heartdisease)
# (age _|_ thalach, restecg, heartdisease | chol, trestbps, fbs, sex)
# (age _|_ thalach, restecg | chol, fbs, sex, heartdisease)
# (age _|_ thalach, restecg | chol, trestbps, sex, heartdisease)
# (age _|_ chol, restecg, heartdisease | thalach, fbs, sex, trestbps)
# (age _|_ chol, restecg | thalach, fbs, sex, heartdisease)
# (age _|_ chol, restecg | heartdisease, thalach, sex, trestbps)
# (age _|_ thalach, chol, restecg | trestbps, fbs, sex, heartdisease)
# (age _|_ thalach | chol, exang, restecg, heartdisease)
# (age _|_ chol | thalach, exang, restecg, heartdisease)
# (age _|_ thalach, chol, heartdisease | fbs, trestbps, exang, restecg)
# (age _|_ thalach, chol | fbs, exang, restecg, heartdisease)
# (age _|_ thalach, chol | trestbps, exang, restecg, heartdisease)
# (age _|_ restecg | thalach, chol, exang, heartdisease)
# (age _|_ thalach, restecg, heartdisease | trestbps, fbs, chol, exang)
# (age _|_ thalach, restecg | fbs, chol, exang, heartdisease)
# (age _|_ thalach, restecg | trestbps, chol, exang, heartdisease)
# (age _|_ chol, restecg, heartdisease | thalach, fbs, trestbps, exang)
# (age _|_ chol, restecg | thalach, fbs, exang, heartdisease)
# (age _|_ chol, restecg | thalach, trestbps, exang, heartdisease)
# (age _|_ thalach, chol, restecg | fbs, trestbps, exang, heartdisease)
# (age _|_ thalach, heartdisease | trestbps, fbs, chol, restecg)
# (age _|_ thalach | fbs, chol, restecg, heartdisease)
# (age _|_ thalach | trestbps, chol, restecg, heartdisease)
# (age _|_ chol, heartdisease | thalach, fbs, trestbps, restecg)
# (age _|_ chol | thalach, fbs, restecg, heartdisease)
# (age _|_ chol | thalach, trestbps, restecg, heartdisease)
# (age _|_ thalach, chol | fbs, trestbps, restecg, heartdisease)
# (age _|_ restecg, heartdisease | thalach, fbs, chol, trestbps)
# (age _|_ restecg | thalach, fbs, chol, heartdisease)
# (age _|_ restecg | heartdisease, thalach, chol, trestbps)
# (age _|_ thalach, restecg | trestbps, fbs, chol, heartdisease)
# (age _|_ chol, restecg | thalach, fbs, trestbps, heartdisease)
# (age _|_ thalach | chol, sex, exang, restecg, heartdisease)
# (age _|_ chol | sex, exang, restecg, thalach, heartdisease)
# (age _|_ thalach, chol, heartdisease | sex, exang, restecg, fbs, trestbps)
# (age _|_ thalach, chol | sex, exang, restecg, fbs, heartdisease)
# (age _|_ thalach, chol | sex, exang, restecg, trestbps, heartdisease)
# (age _|_ restecg | chol, sex, exang, thalach, heartdisease)
# (age _|_ thalach, restecg, heartdisease | chol, sex, exang, fbs, trestbps)
# (age _|_ thalach, restecg | chol, sex, exang, fbs, heartdisease)
# (age _|_ thalach, restecg | chol, sex, exang, trestbps, heartdisease)
# (age _|_ chol, restecg, heartdisease | sex, exang, thalach, fbs, trestbps)
# (age _|_ chol, restecg | sex, exang, thalach, fbs, heartdisease)
# (age _|_ chol, restecg | sex, exang, thalach, trestbps, heartdisease)
# (age _|_ thalach, chol, restecg | sex, exang, fbs, trestbps, heartdisease)
# (age _|_ thalach, heartdisease | chol, sex, restecg, fbs, trestbps)
# (age _|_ thalach | chol, sex, restecg, fbs, heartdisease)
# (age _|_ thalach | chol, sex, restecg, trestbps, heartdisease)
# (age _|_ chol, heartdisease | sex, restecg, thalach, fbs, trestbps)
# (age _|_ chol | sex, restecg, thalach, fbs, heartdisease)
# (age _|_ chol | sex, restecg, thalach, trestbps, heartdisease)
# (age _|_ thalach, chol | sex, restecg, fbs, trestbps, heartdisease)
# (age _|_ restecg, heartdisease | chol, sex, thalach, fbs, trestbps)
# (age _|_ restecg | chol, sex, thalach, fbs, heartdisease)
# (age _|_ restecg | chol, sex, thalach, trestbps, heartdisease)
# (age _|_ thalach, restecg | chol, sex, fbs, trestbps, heartdisease)
# (age _|_ chol, restecg | sex, thalach, fbs, trestbps, heartdisease)
# (age _|_ thalach, heartdisease | chol, exang, restecg, fbs, trestbps)
# (age _|_ thalach | chol, exang, restecg, fbs, heartdisease)
# (age _|_ thalach | chol, exang, restecg, trestbps, heartdisease)
# (age _|_ chol, heartdisease | exang, restecg, thalach, fbs, trestbps)
# (age _|_ chol | exang, restecg, thalach, fbs, heartdisease)
# (age _|_ chol | exang, restecg, thalach, trestbps, heartdisease)
# (age _|_ thalach, chol | exang, restecg, fbs, trestbps, heartdisease)
# (age _|_ restecg, heartdisease | chol, exang, thalach, fbs, trestbps)
# (age _|_ restecg | chol, exang, thalach, fbs, heartdisease)
# (age _|_ restecg | chol, exang, thalach, trestbps, heartdisease)
# (age _|_ thalach, restecg | chol, exang, fbs, trestbps, heartdisease)
# (age _|_ chol, restecg | exang, thalach, fbs, trestbps, heartdisease)
# (age _|_ heartdisease | chol, restecg, thalach, fbs, trestbps)
# (age _|_ thalach | chol, restecg, fbs, trestbps, heartdisease)
# (age _|_ chol | restecg, thalach, fbs, trestbps, heartdisease)
# (age _|_ restecg | chol, thalach, fbs, trestbps, heartdisease)
# (age _|_ thalach, heartdisease | chol, sex, exang, restecg, fbs, trestbps)
# (age _|_ thalach | chol, sex, exang, restecg, fbs, heartdisease)
# (age _|_ thalach | chol, sex, exang, restecg, trestbps, heartdisease)
# (age _|_ chol, heartdisease | sex, exang, restecg, thalach, fbs, trestbps)
# (age _|_ chol | sex, exang, restecg, thalach, fbs, heartdisease)
# (age _|_ chol | sex, exang, restecg, thalach, trestbps, heartdisease)
# (age _|_ thalach, chol | sex, exang, restecg, fbs, trestbps, heartdisease)
# (age _|_ restecg, heartdisease | chol, sex, exang, thalach, fbs, trestbps)
# (age _|_ restecg | chol, sex, exang, thalach, fbs, heartdisease)
# (age _|_ restecg | chol, sex, exang, thalach, trestbps, heartdisease)
# (age _|_ thalach, restecg | chol, sex, exang, fbs, trestbps, heartdisease)
# (age _|_ chol, restecg | sex, exang, thalach, fbs, trestbps, heartdisease)
# (age _|_ heartdisease | chol, sex, restecg, thalach, fbs, trestbps)
# (age _|_ thalach | chol, sex, restecg, fbs, trestbps, heartdisease)
# (age _|_ chol | sex, restecg, thalach, fbs, trestbps, heartdisease)
# (age _|_ restecg | chol, sex, thalach, fbs, trestbps, heartdisease)
# (age _|_ heartdisease | chol, exang, restecg, thalach, fbs, trestbps)
# (age _|_ thalach | chol, exang, restecg, fbs, trestbps, heartdisease)
# (age _|_ chol | exang, restecg, thalach, fbs, trestbps, heartdisease)
# (age _|_ restecg | chol, exang, thalach, fbs, trestbps, heartdisease)
# (age _|_ heartdisease | chol, sex, exang, restecg, thalach, fbs, trestbps)
# (age _|_ thalach | chol, sex, exang, restecg, fbs, trestbps, heartdisease)
# (age _|_ chol | sex, exang, restecg, thalach, fbs, trestbps, heartdisease)
# (age _|_ restecg | chol, sex, exang, thalach, fbs, trestbps, heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ thalach, chol, restecg | heartdisease)
# (trestbps _|_ fbs | sex, age)
# (trestbps _|_ thalach, chol, restecg | sex, heartdisease)
# (trestbps _|_ fbs | exang, age)
# (trestbps _|_ thalach, chol, restecg | exang, heartdisease)
# (trestbps _|_ thalach, chol | restecg, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease)
# (trestbps _|_ chol, restecg | thalach, heartdisease)
# (trestbps _|_ thalach, chol, restecg | fbs, heartdisease)
# (trestbps _|_ thalach, chol, restecg | heartdisease, age)
# (trestbps _|_ fbs | sex, exang, age)
# (trestbps _|_ thalach, chol, restecg | sex, exang, heartdisease)
# (trestbps _|_ thalach, chol | sex, restecg, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, heartdisease)
# (trestbps _|_ chol, restecg | thalach, sex, heartdisease)
# (trestbps _|_ thalach, chol, restecg | fbs, sex, heartdisease)
# (trestbps _|_ thalach, chol, restecg | sex, heartdisease, age)
# (trestbps _|_ thalach, chol | exang, restecg, heartdisease)
# (trestbps _|_ thalach, restecg | chol, exang, heartdisease)
# (trestbps _|_ chol, restecg | thalach, exang, heartdisease)
# (trestbps _|_ thalach, chol, restecg | fbs, exang, heartdisease)
# (trestbps _|_ thalach, chol, restecg | exang, heartdisease, age)
# (trestbps _|_ thalach | chol, restecg, heartdisease)
# (trestbps _|_ chol | thalach, restecg, heartdisease)
# (trestbps _|_ thalach, chol | fbs, restecg, heartdisease)
# (trestbps _|_ thalach, chol | restecg, heartdisease, age)
# (trestbps _|_ restecg | thalach, chol, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease, age)
# (trestbps _|_ chol, restecg | thalach, fbs, heartdisease)
# (trestbps _|_ chol, restecg | thalach, heartdisease, age)
# (trestbps _|_ thalach, chol, restecg | fbs, heartdisease, age)
# (trestbps _|_ thalach, chol | sex, exang, restecg, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, exang, heartdisease)
# (trestbps _|_ chol, restecg | thalach, sex, exang, heartdisease)
# (trestbps _|_ thalach, chol, restecg | fbs, sex, exang, heartdisease)
# (trestbps _|_ thalach, chol, restecg | sex, exang, heartdisease, age)
# (trestbps _|_ thalach | chol, sex, restecg, heartdisease)
# (trestbps _|_ chol | thalach, sex, restecg, heartdisease)
# (trestbps _|_ thalach, chol | fbs, sex, restecg, heartdisease)
# (trestbps _|_ thalach, chol | sex, restecg, heartdisease, age)
# (trestbps _|_ restecg | chol, thalach, sex, heartdisease)
# (trestbps _|_ thalach, restecg | chol, fbs, sex, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, heartdisease, age)
# (trestbps _|_ chol, restecg | thalach, fbs, sex, heartdisease)
# (trestbps _|_ chol, restecg | thalach, sex, heartdisease, age)
# (trestbps _|_ thalach, chol, restecg | fbs, sex, heartdisease, age)
# (trestbps _|_ thalach | chol, exang, restecg, heartdisease)
# (trestbps _|_ chol | thalach, exang, restecg, heartdisease)
# (trestbps _|_ thalach, chol | fbs, exang, restecg, heartdisease)
# (trestbps _|_ thalach, chol | exang, restecg, heartdisease, age)
# (trestbps _|_ restecg | thalach, chol, exang, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, chol, exang, heartdisease)
# (trestbps _|_ thalach, restecg | chol, exang, heartdisease, age)
# (trestbps _|_ chol, restecg | thalach, fbs, exang, heartdisease)
# (trestbps _|_ chol, restecg | thalach, exang, heartdisease, age)
# (trestbps _|_ thalach, chol, restecg | fbs, exang, heartdisease, age)
# (trestbps _|_ thalach | fbs, chol, restecg, heartdisease)
# (trestbps _|_ thalach | chol, restecg, heartdisease, age)
# (trestbps _|_ chol | thalach, fbs, restecg, heartdisease)
# (trestbps _|_ chol | thalach, restecg, heartdisease, age)
# (trestbps _|_ thalach, chol | fbs, restecg, heartdisease, age)
# (trestbps _|_ restecg | thalach, fbs, chol, heartdisease)
# (trestbps _|_ restecg | thalach, chol, heartdisease, age)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease, age)
# (trestbps _|_ chol, restecg | thalach, fbs, heartdisease, age)
# (trestbps _|_ thalach | chol, sex, exang, restecg, heartdisease)
# (trestbps _|_ chol | sex, exang, restecg, thalach, heartdisease)
# (trestbps _|_ thalach, chol | sex, exang, restecg, fbs, heartdisease)
# (trestbps _|_ thalach, chol | sex, exang, restecg, age, heartdisease)
# (trestbps _|_ restecg | chol, sex, exang, thalach, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, exang, fbs, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, exang, age, heartdisease)
# (trestbps _|_ chol, restecg | sex, exang, thalach, fbs, heartdisease)
# (trestbps _|_ chol, restecg | sex, exang, thalach, age, heartdisease)
# (trestbps _|_ thalach, chol, restecg | sex, exang, fbs, age, heartdisease)
# (trestbps _|_ thalach | chol, sex, restecg, fbs, heartdisease)
# (trestbps _|_ thalach | chol, sex, restecg, age, heartdisease)
# (trestbps _|_ chol | sex, restecg, thalach, fbs, heartdisease)
# (trestbps _|_ chol | sex, restecg, thalach, age, heartdisease)
# (trestbps _|_ thalach, chol | sex, restecg, fbs, age, heartdisease)
# (trestbps _|_ restecg | chol, sex, thalach, fbs, heartdisease)
# (trestbps _|_ restecg | chol, sex, thalach, age, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, fbs, age, heartdisease)
# (trestbps _|_ chol, restecg | sex, thalach, fbs, age, heartdisease)
# (trestbps _|_ thalach | chol, exang, restecg, fbs, heartdisease)
# (trestbps _|_ thalach | chol, exang, restecg, age, heartdisease)
# (trestbps _|_ chol | exang, restecg, thalach, fbs, heartdisease)
# (trestbps _|_ chol | exang, restecg, thalach, age, heartdisease)
# (trestbps _|_ thalach, chol | exang, restecg, fbs, age, heartdisease)
# (trestbps _|_ restecg | chol, exang, thalach, fbs, heartdisease)
# (trestbps _|_ restecg | chol, exang, thalach, age, heartdisease)
# (trestbps _|_ thalach, restecg | chol, exang, fbs, age, heartdisease)
# (trestbps _|_ chol, restecg | exang, thalach, fbs, age, heartdisease)
# (trestbps _|_ thalach | chol, restecg, fbs, age, heartdisease)
# (trestbps _|_ chol | restecg, thalach, fbs, age, heartdisease)
# (trestbps _|_ restecg | chol, thalach, fbs, age, heartdisease)
# (trestbps _|_ thalach | chol, sex, exang, restecg, fbs, heartdisease)
# (trestbps _|_ thalach | chol, sex, exang, restecg, age, heartdisease)
# (trestbps _|_ chol | sex, exang, restecg, thalach, fbs, heartdisease)
# (trestbps _|_ chol | sex, exang, restecg, thalach, age, heartdisease)
# (trestbps _|_ thalach, chol | sex, exang, restecg, fbs, age, heartdisease)
# (trestbps _|_ restecg | chol, sex, exang, thalach, fbs, heartdisease)
# (trestbps _|_ restecg | chol, sex, exang, thalach, age, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, exang, fbs, age, heartdisease)
# (trestbps _|_ chol, restecg | sex, exang, thalach, fbs, age, heartdisease)
# (trestbps _|_ thalach | chol, sex, restecg, fbs, age, heartdisease)
# (trestbps _|_ chol | sex, restecg, thalach, fbs, age, heartdisease)
# (trestbps _|_ restecg | chol, sex, thalach, fbs, age, heartdisease)
# (trestbps _|_ thalach | chol, exang, restecg, fbs, age, heartdisease)
# (trestbps _|_ chol | exang, restecg, thalach, fbs, age, heartdisease)
# (trestbps _|_ restecg | chol, exang, thalach, fbs, age, heartdisease)
# (trestbps _|_ thalach | chol, sex, exang, restecg, fbs, age, heartdisease)
# (trestbps _|_ chol | sex, exang, restecg, thalach, fbs, age, heartdisease)
# (trestbps _|_ restecg | chol, sex, exang, thalach, fbs, age, heartdisease)
# (fbs _|_ sex, exang)
# (fbs _|_ exang | sex)
# (fbs _|_ sex | exang)
# (fbs _|_ trestbps, sex, exang | age)
# (fbs _|_ thalach, chol, restecg | heartdisease)
# (fbs _|_ trestbps, exang | sex, age)
# (fbs _|_ thalach, chol, restecg | sex, heartdisease)
# (fbs _|_ trestbps, sex | exang, age)
# (fbs _|_ thalach, chol, restecg | exang, heartdisease)
# (fbs _|_ thalach, chol | restecg, heartdisease)
# (fbs _|_ thalach, restecg | chol, heartdisease)
# (fbs _|_ chol, restecg | thalach, heartdisease)
# (fbs _|_ sex, exang | trestbps, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, age)
# (fbs _|_ thalach, chol, restecg | trestbps, heartdisease)
# (fbs _|_ trestbps | sex, exang, age)
# (fbs _|_ thalach, chol, restecg | sex, exang, heartdisease)
# (fbs _|_ thalach, chol | sex, restecg, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, heartdisease)
# (fbs _|_ chol, restecg | thalach, sex, heartdisease)
# (fbs _|_ exang | trestbps, sex, age)
# (fbs _|_ thalach, chol, restecg | sex, heartdisease, age)
# (fbs _|_ thalach, chol, restecg | trestbps, sex, heartdisease)
# (fbs _|_ thalach, chol | exang, restecg, heartdisease)
# (fbs _|_ thalach, restecg | chol, exang, heartdisease)
# (fbs _|_ chol, restecg | thalach, exang, heartdisease)
# (fbs _|_ sex | trestbps, exang, age)
# (fbs _|_ thalach, chol, restecg | exang, heartdisease, age)
# (fbs _|_ thalach, chol, restecg | trestbps, exang, heartdisease)
# (fbs _|_ thalach | chol, restecg, heartdisease)
# (fbs _|_ chol | thalach, restecg, heartdisease)
# (fbs _|_ sex, exang | trestbps, restecg, age)
# (fbs _|_ thalach, chol | restecg, heartdisease, age)
# (fbs _|_ thalach, chol | trestbps, restecg, heartdisease)
# (fbs _|_ restecg | thalach, chol, heartdisease)
# (fbs _|_ sex, exang | trestbps, chol, age)
# (fbs _|_ thalach, restecg | chol, heartdisease, age)
# (fbs _|_ thalach, restecg | trestbps, chol, heartdisease)
# (fbs _|_ sex, exang | thalach, trestbps, age)
# (fbs _|_ chol, restecg | thalach, heartdisease, age)
# (fbs _|_ chol, restecg | thalach, trestbps, heartdisease)
# (fbs _|_ chol, thalach, sex, exang, restecg | trestbps, heartdisease, age)
# (fbs _|_ thalach, chol | sex, exang, restecg, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, exang, heartdisease)
# (fbs _|_ chol, restecg | thalach, sex, exang, heartdisease)
# (fbs _|_ thalach, chol, restecg | sex, exang, heartdisease, age)
# (fbs _|_ thalach, chol, restecg | trestbps, sex, exang, heartdisease)
# (fbs _|_ thalach | chol, sex, restecg, heartdisease)
# (fbs _|_ chol | thalach, sex, restecg, heartdisease)
# (fbs _|_ exang | trestbps, sex, restecg, age)
# (fbs _|_ thalach, chol | sex, restecg, heartdisease, age)
# (fbs _|_ thalach, chol | trestbps, sex, restecg, heartdisease)
# (fbs _|_ restecg | chol, thalach, sex, heartdisease)
# (fbs _|_ exang | chol, trestbps, sex, age)
# (fbs _|_ thalach, restecg | chol, sex, heartdisease, age)
# (fbs _|_ thalach, restecg | chol, trestbps, sex, heartdisease)
# (fbs _|_ exang | thalach, sex, trestbps, age)
# (fbs _|_ chol, restecg | thalach, sex, heartdisease, age)
# (fbs _|_ chol, restecg | heartdisease, thalach, sex, trestbps)
# (fbs _|_ thalach, chol, exang, restecg | trestbps, sex, heartdisease, age)
# (fbs _|_ thalach | chol, exang, restecg, heartdisease)
# (fbs _|_ chol | thalach, exang, restecg, heartdisease)
# (fbs _|_ sex | trestbps, exang, restecg, age)
# (fbs _|_ thalach, chol | exang, restecg, heartdisease, age)
# (fbs _|_ thalach, chol | trestbps, exang, restecg, heartdisease)
# (fbs _|_ restecg | thalach, chol, exang, heartdisease)
# (fbs _|_ sex | trestbps, chol, exang, age)
# (fbs _|_ thalach, restecg | chol, exang, heartdisease, age)
# (fbs _|_ thalach, restecg | trestbps, chol, exang, heartdisease)
# (fbs _|_ sex | thalach, trestbps, exang, age)
# (fbs _|_ chol, restecg | thalach, exang, heartdisease, age)
# (fbs _|_ chol, restecg | thalach, trestbps, exang, heartdisease)
# (fbs _|_ thalach, sex, chol, restecg | trestbps, exang, heartdisease, age)
# (fbs _|_ sex, exang | trestbps, chol, restecg, age)
# (fbs _|_ thalach | chol, restecg, heartdisease, age)
# (fbs _|_ thalach | trestbps, chol, restecg, heartdisease)
# (fbs _|_ sex, exang | thalach, trestbps, restecg, age)
# (fbs _|_ chol | thalach, restecg, heartdisease, age)
# (fbs _|_ chol | thalach, trestbps, restecg, heartdisease)
# (fbs _|_ thalach, sex, chol, exang | trestbps, restecg, heartdisease, age)
# (fbs _|_ sex, exang | thalach, chol, trestbps, age)
# (fbs _|_ restecg | thalach, chol, heartdisease, age)
# (fbs _|_ restecg | heartdisease, thalach, chol, trestbps)
# (fbs _|_ thalach, sex, exang, restecg | trestbps, chol, heartdisease, age)
# (fbs _|_ sex, chol, exang, restecg | thalach, trestbps, heartdisease, age)
# (fbs _|_ thalach | chol, sex, exang, restecg, heartdisease)
# (fbs _|_ chol | sex, exang, restecg, thalach, heartdisease)
# (fbs _|_ thalach, chol | sex, exang, restecg, age, heartdisease)
# (fbs _|_ thalach, chol | sex, exang, restecg, trestbps, heartdisease)
# (fbs _|_ restecg | chol, sex, exang, thalach, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, exang, age, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, exang, trestbps, heartdisease)
# (fbs _|_ chol, restecg | sex, exang, thalach, age, heartdisease)
# (fbs _|_ chol, restecg | sex, exang, thalach, trestbps, heartdisease)
# (fbs _|_ thalach, chol, restecg | sex, exang, age, trestbps, heartdisease)
# (fbs _|_ exang | chol, sex, restecg, age, trestbps)
# (fbs _|_ thalach | chol, sex, restecg, age, heartdisease)
# (fbs _|_ thalach | chol, sex, restecg, trestbps, heartdisease)
# (fbs _|_ exang | sex, restecg, thalach, age, trestbps)
# (fbs _|_ chol | sex, restecg, thalach, age, heartdisease)
# (fbs _|_ chol | sex, restecg, thalach, trestbps, heartdisease)
# (fbs _|_ thalach, chol, exang | sex, restecg, age, trestbps, heartdisease)
# (fbs _|_ exang | chol, sex, thalach, age, trestbps)
# (fbs _|_ restecg | chol, sex, thalach, age, heartdisease)
# (fbs _|_ restecg | chol, sex, thalach, trestbps, heartdisease)
# (fbs _|_ thalach, exang, restecg | chol, sex, age, trestbps, heartdisease)
# (fbs _|_ chol, exang, restecg | sex, thalach, age, trestbps, heartdisease)
# (fbs _|_ sex | chol, exang, restecg, age, trestbps)
# (fbs _|_ thalach | chol, exang, restecg, age, heartdisease)
# (fbs _|_ thalach | chol, exang, restecg, trestbps, heartdisease)
# (fbs _|_ sex | exang, restecg, thalach, age, trestbps)
# (fbs _|_ chol | exang, restecg, thalach, age, heartdisease)
# (fbs _|_ chol | exang, restecg, thalach, trestbps, heartdisease)
# (fbs _|_ thalach, sex, chol | exang, restecg, age, trestbps, heartdisease)
# (fbs _|_ sex | chol, exang, thalach, age, trestbps)
# (fbs _|_ restecg | chol, exang, thalach, age, heartdisease)
# (fbs _|_ restecg | chol, exang, thalach, trestbps, heartdisease)
# (fbs _|_ thalach, sex, restecg | chol, exang, age, trestbps, heartdisease)
# (fbs _|_ sex, chol, restecg | exang, thalach, age, trestbps, heartdisease)
# (fbs _|_ sex, exang | chol, restecg, thalach, age, trestbps)
# (fbs _|_ thalach, sex, exang | chol, restecg, age, trestbps, heartdisease)
# (fbs _|_ sex, chol, exang | restecg, thalach, age, trestbps, heartdisease)
# (fbs _|_ sex, exang, restecg | chol, thalach, age, trestbps, heartdisease)
# (fbs _|_ thalach | chol, sex, exang, restecg, age, heartdisease)
# (fbs _|_ thalach | chol, sex, exang, restecg, trestbps, heartdisease)
# (fbs _|_ chol | sex, exang, restecg, thalach, age, heartdisease)
# (fbs _|_ chol | sex, exang, restecg, thalach, trestbps, heartdisease)
# (fbs _|_ thalach, chol | sex, exang, restecg, age, trestbps, heartdisease)
# (fbs _|_ restecg | chol, sex, exang, thalach, age, heartdisease)
# (fbs _|_ restecg | chol, sex, exang, thalach, trestbps, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, exang, age, trestbps, heartdisease)
# (fbs _|_ chol, restecg | sex, exang, thalach, age, trestbps, heartdisease)
# (fbs _|_ exang | chol, sex, restecg, thalach, age, trestbps)
# (fbs _|_ thalach, exang | chol, sex, restecg, age, trestbps, heartdisease)
# (fbs _|_ chol, exang | sex, restecg, thalach, age, trestbps, heartdisease)
# (fbs _|_ exang, restecg | chol, sex, thalach, age, trestbps, heartdisease)
# (fbs _|_ sex | chol, exang, restecg, thalach, age, trestbps)
# (fbs _|_ thalach, sex | chol, exang, restecg, age, trestbps, heartdisease)
# (fbs _|_ sex, chol | exang, restecg, thalach, age, trestbps, heartdisease)
# (fbs _|_ sex, restecg | chol, exang, thalach, age, trestbps, heartdisease)
# (fbs _|_ sex, exang | chol, restecg, thalach, age, trestbps, heartdisease)
# (fbs _|_ thalach | chol, sex, exang, restecg, age, trestbps, heartdisease)
# (fbs _|_ chol | sex, exang, restecg, thalach, age, trestbps, heartdisease)
# (fbs _|_ restecg | chol, sex, exang, thalach, age, trestbps, heartdisease)
# (fbs _|_ exang | chol, sex, restecg, thalach, age, trestbps, heartdisease)
# (fbs _|_ sex | chol, exang, restecg, thalach, age, trestbps, heartdisease)
# (sex _|_ fbs, exang, age)
# (sex _|_ fbs, age | exang)
# (sex _|_ exang, age | fbs)
# (sex _|_ fbs, exang | age)
# (sex _|_ thalach, chol, restecg | heartdisease)
# (sex _|_ age | fbs, exang)
# (sex _|_ fbs | exang, age)
# (sex _|_ thalach, chol, restecg | exang, heartdisease)
# (sex _|_ thalach, chol | restecg, heartdisease)
# (sex _|_ thalach, restecg | chol, heartdisease)
# (sex _|_ chol, restecg | thalach, heartdisease)
# (sex _|_ exang | fbs, age)
# (sex _|_ thalach, chol, restecg, heartdisease | fbs, trestbps)
# (sex _|_ thalach, chol, restecg | fbs, heartdisease)
# (sex _|_ thalach, fbs, chol, restecg, heartdisease | trestbps, age)
# (sex _|_ thalach, chol, restecg | heartdisease, age)
# (sex _|_ thalach, chol, restecg | trestbps, heartdisease)
# (sex _|_ thalach, chol | exang, restecg, heartdisease)
# (sex _|_ thalach, restecg | chol, exang, heartdisease)
# (sex _|_ chol, restecg | thalach, exang, heartdisease)
# (sex _|_ thalach, chol, restecg, heartdisease | fbs, trestbps, exang)
# (sex _|_ thalach, chol, restecg | fbs, exang, heartdisease)
# (sex _|_ thalach, fbs, chol, restecg, heartdisease | trestbps, exang, age)
# (sex _|_ thalach, chol, restecg | exang, heartdisease, age)
# (sex _|_ thalach, chol, restecg | trestbps, exang, heartdisease)
# (sex _|_ thalach | chol, restecg, heartdisease)
# ...
# (thalach _|_ fbs, exang, age | chol, sex, restecg, trestbps, heartdisease)
# (thalach _|_ exang | sex, restecg, fbs, age, trestbps)
# (thalach _|_ chol, trestbps, exang | sex, restecg, fbs, age, heartdisease)
# (thalach _|_ chol, exang, age | sex, restecg, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, chol, exang | sex, restecg, age, trestbps, heartdisease)
# (thalach _|_ exang | chol, sex, fbs, age, trestbps)
# (thalach _|_ trestbps, exang, restecg | chol, sex, fbs, age, heartdisease)
# (thalach _|_ exang, restecg, age | chol, sex, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, exang, restecg | chol, sex, age, trestbps, heartdisease)
# (thalach _|_ chol, exang, restecg | sex, fbs, age, trestbps, heartdisease)
# (thalach _|_ sex, age | chol, exang, restecg, fbs, trestbps)
# (thalach _|_ sex, trestbps, age | chol, exang, restecg, fbs, heartdisease)
# (thalach _|_ sex | chol, exang, restecg, age, trestbps)
# (thalach _|_ sex, fbs, trestbps | chol, exang, restecg, age, heartdisease)
# (thalach _|_ fbs, sex, age | chol, exang, restecg, trestbps, heartdisease)
# (thalach _|_ sex | exang, restecg, fbs, age, trestbps)
# (thalach _|_ trestbps, sex, chol | exang, restecg, fbs, age, heartdisease)
# (thalach _|_ sex, chol, age | exang, restecg, fbs, trestbps, heartdisease)
# (thalach _|_ sex, fbs, chol | exang, restecg, age, trestbps, heartdisease)
# (thalach _|_ sex | chol, exang, fbs, age, trestbps)
# (thalach _|_ sex, trestbps, restecg | chol, exang, fbs, age, heartdisease)
# (thalach _|_ sex, restecg, age | chol, exang, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, sex, restecg | chol, exang, age, trestbps, heartdisease)
# (thalach _|_ sex, chol, restecg | exang, fbs, age, trestbps, heartdisease)
# (thalach _|_ sex, exang | chol, restecg, fbs, age, trestbps)
# (thalach _|_ sex, trestbps, exang | chol, restecg, fbs, age, heartdisease)
# (thalach _|_ sex, exang, age | chol, restecg, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, sex, exang | chol, restecg, age, trestbps, heartdisease)
# (thalach _|_ sex, chol, exang | restecg, fbs, age, trestbps, heartdisease)
# (thalach _|_ sex, exang, restecg | chol, fbs, age, trestbps, heartdisease)
# (thalach _|_ age | chol, sex, exang, restecg, fbs, trestbps)
# (thalach _|_ trestbps, age | chol, sex, exang, restecg, fbs, heartdisease)
# (thalach _|_ fbs, trestbps | chol, sex, exang, restecg, age, heartdisease)
# (thalach _|_ fbs, age | chol, sex, exang, restecg, trestbps, heartdisease)
# (thalach _|_ chol, trestbps | sex, exang, restecg, fbs, age, heartdisease)
# (thalach _|_ chol, age | sex, exang, restecg, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, chol | sex, exang, restecg, age, trestbps, heartdisease)
# (thalach _|_ trestbps, restecg | chol, sex, exang, fbs, age, heartdisease)
# (thalach _|_ restecg, age | chol, sex, exang, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, restecg | chol, sex, exang, age, trestbps, heartdisease)
# (thalach _|_ chol, restecg | sex, exang, fbs, age, trestbps, heartdisease)
# (thalach _|_ exang | chol, sex, restecg, fbs, age, trestbps)
# (thalach _|_ trestbps, exang | chol, sex, restecg, fbs, age, heartdisease)
# (thalach _|_ exang, age | chol, sex, restecg, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, exang | chol, sex, restecg, age, trestbps, heartdisease)
# (thalach _|_ chol, exang | sex, restecg, fbs, age, trestbps, heartdisease)
# (thalach _|_ exang, restecg | chol, sex, fbs, age, trestbps, heartdisease)
# (thalach _|_ sex | chol, exang, restecg, fbs, age, trestbps)
# (thalach _|_ sex, trestbps | chol, exang, restecg, fbs, age, heartdisease)
# (thalach _|_ sex, age | chol, exang, restecg, fbs, trestbps, heartdisease)
# (thalach _|_ fbs, sex | chol, exang, restecg, age, trestbps, heartdisease)
# (thalach _|_ sex, chol | exang, restecg, fbs, age, trestbps, heartdisease)
# (thalach _|_ sex, restecg | chol, exang, fbs, age, trestbps, heartdisease)
# (thalach _|_ sex, exang | chol, restecg, fbs, age, trestbps, heartdisease)
# (thalach _|_ trestbps | chol, sex, exang, restecg, fbs, age, heartdisease)
# (thalach _|_ age | chol, sex, exang, restecg, fbs, trestbps, heartdisease)
# (thalach _|_ fbs | chol, sex, exang, restecg, age, trestbps, heartdisease)
# (thalach _|_ chol | sex, exang, restecg, fbs, age, trestbps, heartdisease)
# (thalach _|_ restecg | chol, sex, exang, fbs, age, trestbps, heartdisease)
# (thalach _|_ exang | chol, sex, restecg, fbs, age, trestbps, heartdisease)
# (thalach _|_ sex | chol, exang, restecg, fbs, age, trestbps, heartdisease)
# (chol _|_ thalach, fbs, trestbps, age, sex, exang, restecg | heartdisease)
# (chol _|_ thalach, fbs, age, trestbps, exang, restecg | sex, heartdisease)
# (chol _|_ thalach, fbs, trestbps, age, sex, restecg | exang, heartdisease)
# (chol _|_ thalach, fbs, trestbps, age, sex, exang | restecg, heartdisease)
# (chol _|_ trestbps, fbs, age, sex, exang, restecg | thalach, heartdisease)
# (chol _|_ sex, exang, age | fbs, trestbps)
# (chol _|_ thalach, trestbps, age, sex, exang, restecg | fbs, heartdisease)
# (chol _|_ sex, exang | trestbps, age)
# (chol _|_ thalach, fbs, trestbps, sex, exang, restecg | heartdisease, age)
# (chol _|_ thalach, fbs, age, sex, exang, restecg | trestbps, heartdisease)
# (chol _|_ thalach, fbs, age, trestbps, restecg | sex, exang, heartdisease)
# (chol _|_ thalach, fbs, age, trestbps, exang | sex, restecg, heartdisease)
# (chol _|_ fbs, age, trestbps, exang, restecg | thalach, sex, heartdisease)
# (chol _|_ exang, age | trestbps, fbs, sex)
# (chol _|_ thalach, age, trestbps, exang, restecg | fbs, sex, heartdisease)
# (chol _|_ exang | trestbps, sex, age)
# (chol _|_ thalach, fbs, trestbps, exang, restecg | sex, heartdisease, age)
# (chol _|_ thalach, fbs, age, exang, restecg | trestbps, sex, heartdisease)
# (chol _|_ thalach, fbs, trestbps, age, sex | exang, restecg, heartdisease)
# (chol _|_ trestbps, fbs, age, sex, restecg | thalach, exang, heartdisease)
# (chol _|_ sex, age | fbs, trestbps, exang)
# (chol _|_ thalach, trestbps, age, sex, restecg | fbs, exang, heartdisease)
# (chol _|_ sex | trestbps, exang, age)
# (chol _|_ thalach, fbs, trestbps, sex, restecg | exang, heartdisease, age)
# (chol _|_ thalach, fbs, age, sex, restecg | trestbps, exang, heartdisease)
# (chol _|_ trestbps, fbs, age, sex, exang | thalach, restecg, heartdisease)
# (chol _|_ sex, exang, age | fbs, trestbps, restecg)
# (chol _|_ thalach, trestbps, age, sex, exang | fbs, restecg, heartdisease)
# (chol _|_ sex, exang | trestbps, restecg, age)
# (chol _|_ thalach, fbs, trestbps, sex, exang | restecg, heartdisease, age)
# (chol _|_ thalach, fbs, age, sex, exang | trestbps, restecg, heartdisease)
# (chol _|_ sex, exang, age | thalach, fbs, trestbps)
# (chol _|_ trestbps, age, sex, exang, restecg | thalach, fbs, heartdisease)
# (chol _|_ sex, exang | thalach, trestbps, age)
# (chol _|_ trestbps, fbs, sex, exang, restecg | thalach, heartdisease, age)
# (chol _|_ fbs, age, sex, exang, restecg | thalach, trestbps, heartdisease)
# (chol _|_ sex, exang | fbs, trestbps, age)
# (chol _|_ thalach, trestbps, sex, exang, restecg | fbs, heartdisease, age)
# (chol _|_ thalach, age, sex, exang, restecg | fbs, trestbps, heartdisease)
# (chol _|_ thalach, fbs, sex, exang, restecg | trestbps, heartdisease, age)
# (chol _|_ thalach, fbs, trestbps, age | sex, exang, restecg, heartdisease)
# (chol _|_ fbs, trestbps, restecg, age | thalach, sex, exang, heartdisease)
# (chol _|_ age | trestbps, fbs, sex, exang)
# (chol _|_ thalach, trestbps, restecg, age | fbs, sex, exang, heartdisease)
# (chol _|_ thalach, fbs, trestbps, restecg | sex, exang, heartdisease, age)
# (chol _|_ thalach, fbs, restecg, age | trestbps, sex, exang, heartdisease)
# (chol _|_ fbs, trestbps, exang, age | thalach, sex, restecg, heartdisease)
# (chol _|_ exang, age | trestbps, fbs, sex, restecg)
# (chol _|_ thalach, trestbps, exang, age | fbs, sex, restecg, heartdisease)
# (chol _|_ exang | trestbps, sex, restecg, age)
# (chol _|_ thalach, fbs, trestbps, exang | sex, restecg, heartdisease, age)
# (chol _|_ thalach, fbs, exang, age | trestbps, sex, restecg, heartdisease)
# (chol _|_ exang, age | thalach, fbs, sex, trestbps)
# (chol _|_ trestbps, exang, restecg, age | thalach, fbs, sex, heartdisease)
# (chol _|_ exang | thalach, sex, trestbps, age)
# (chol _|_ fbs, trestbps, exang, restecg | thalach, sex, heartdisease, age)
# (chol _|_ fbs, exang, restecg, age | heartdisease, thalach, sex, trestbps)
# (chol _|_ exang | trestbps, fbs, sex, age)
# (chol _|_ thalach, trestbps, exang, restecg | fbs, sex, heartdisease, age)
# (chol _|_ thalach, exang, restecg, age | trestbps, fbs, sex, heartdisease)
# (chol _|_ thalach, fbs, exang, restecg | trestbps, sex, heartdisease, age)
# (chol _|_ sex, fbs, trestbps, age | thalach, exang, restecg, heartdisease)
# (chol _|_ sex, age | fbs, trestbps, exang, restecg)
# (chol _|_ thalach, sex, trestbps, age | fbs, exang, restecg, heartdisease)
# (chol _|_ sex | trestbps, exang, restecg, age)
# (chol _|_ thalach, fbs, sex, trestbps | exang, restecg, heartdisease, age)
# (chol _|_ thalach, fbs, sex, age | trestbps, exang, restecg, heartdisease)
# (chol _|_ sex, age | thalach, fbs, trestbps, exang)
# (chol _|_ sex, trestbps, restecg, age | thalach, fbs, exang, heartdisease)
# (chol _|_ sex | thalach, trestbps, exang, age)
# (chol _|_ sex, fbs, trestbps, restecg | thalach, exang, heartdisease, age)
# (chol _|_ fbs, sex, restecg, age | thalach, trestbps, exang, heartdisease)
# (chol _|_ sex | fbs, trestbps, exang, age)
# (chol _|_ thalach, sex, restecg, trestbps | fbs, exang, heartdisease, age)
# (chol _|_ thalach, sex, restecg, age | fbs, trestbps, exang, heartdisease)
# (chol _|_ thalach, fbs, sex, restecg | trestbps, exang, heartdisease, age)
# (chol _|_ sex, exang, age | thalach, fbs, trestbps, restecg)
# (chol _|_ sex, trestbps, exang, age | thalach, fbs, restecg, heartdisease)
# (chol _|_ sex, exang | thalach, trestbps, restecg, age)
# (chol _|_ sex, fbs, trestbps, exang | thalach, restecg, heartdisease, age)
# (chol _|_ fbs, sex, exang, age | thalach, trestbps, restecg, heartdisease)
# (chol _|_ sex, exang | fbs, trestbps, restecg, age)
# (chol _|_ thalach, sex, exang, trestbps | fbs, restecg, heartdisease, age)
# (chol _|_ thalach, sex, exang, age | fbs, trestbps, restecg, heartdisease)
# (chol _|_ thalach, fbs, sex, exang | trestbps, restecg, heartdisease, age)
# (chol _|_ sex, exang | thalach, fbs, trestbps, age)
# (chol _|_ sex, trestbps, exang, restecg | thalach, fbs, heartdisease, age)
# (chol _|_ sex, exang, restecg, age | thalach, fbs, trestbps, heartdisease)
# (chol _|_ fbs, sex, exang, restecg | thalach, trestbps, heartdisease, age)
# (chol _|_ thalach, sex, exang, restecg | fbs, trestbps, heartdisease, age)
# (chol _|_ fbs, trestbps, age | sex, exang, restecg, thalach, heartdisease)
# (chol _|_ age | sex, exang, restecg, fbs, trestbps)
# (chol _|_ thalach, trestbps, age | sex, exang, restecg, fbs, heartdisease)
# (chol _|_ thalach, fbs, trestbps | sex, exang, restecg, age, heartdisease)
# (chol _|_ thalach, fbs, age | sex, exang, restecg, trestbps, heartdisease)
# (chol _|_ age | sex, exang, thalach, fbs, trestbps)
# (chol _|_ trestbps, restecg, age | sex, exang, thalach, fbs, heartdisease)
# (chol _|_ fbs, trestbps, restecg | sex, exang, thalach, age, heartdisease)
# (chol _|_ fbs, restecg, age | sex, exang, thalach, trestbps, heartdisease)
# (chol _|_ thalach, trestbps, restecg | sex, exang, fbs, age, heartdisease)
# (chol _|_ thalach, restecg, age | sex, exang, fbs, trestbps, heartdisease)
# (chol _|_ thalach, fbs, restecg | sex, exang, age, trestbps, heartdisease)
# (chol _|_ exang, age | sex, restecg, thalach, fbs, trestbps)
# (chol _|_ trestbps, exang, age | sex, restecg, thalach, fbs, heartdisease)
# (chol _|_ exang | sex, restecg, thalach, age, trestbps)
# (chol _|_ fbs, trestbps, exang | sex, restecg, thalach, age, heartdisease)
# (chol _|_ fbs, exang, age | sex, restecg, thalach, trestbps, heartdisease)
# (chol _|_ exang | sex, restecg, fbs, age, trestbps)
# (chol _|_ thalach, trestbps, exang | sex, restecg, fbs, age, heartdisease)
# (chol _|_ thalach, exang, age | sex, restecg, fbs, trestbps, heartdisease)
# (chol _|_ thalach, fbs, exang | sex, restecg, age, trestbps, heartdisease)
# (chol _|_ exang | sex, thalach, fbs, age, trestbps)
# (chol _|_ trestbps, exang, restecg | sex, thalach, fbs, age, heartdisease)
# (chol _|_ exang, restecg, age | sex, thalach, fbs, trestbps, heartdisease)
# (chol _|_ fbs, exang, restecg | sex, thalach, age, trestbps, heartdisease)
# (chol _|_ thalach, exang, restecg | sex, fbs, age, trestbps, heartdisease)
# (chol _|_ sex, age | exang, restecg, thalach, fbs, trestbps)
# (chol _|_ sex, trestbps, age | exang, restecg, thalach, fbs, heartdisease)
# (chol _|_ sex | exang, restecg, thalach, age, trestbps)
# (chol _|_ sex, fbs, trestbps | exang, restecg, thalach, age, heartdisease)
# (chol _|_ fbs, sex, age | exang, restecg, thalach, trestbps, heartdisease)
# (chol _|_ sex | exang, restecg, fbs, age, trestbps)
# (chol _|_ thalach, sex, trestbps | exang, restecg, fbs, age, heartdisease)
# (chol _|_ thalach, sex, age | exang, restecg, fbs, trestbps, heartdisease)
# (chol _|_ thalach, fbs, sex | exang, restecg, age, trestbps, heartdisease)
# (chol _|_ sex | exang, thalach, fbs, age, trestbps)
# (chol _|_ sex, trestbps, restecg | exang, thalach, fbs, age, heartdisease)
# (chol _|_ sex, restecg, age | exang, thalach, fbs, trestbps, heartdisease)
# (chol _|_ fbs, sex, restecg | exang, thalach, age, trestbps, heartdisease)
# (chol _|_ thalach, sex, restecg | exang, fbs, age, trestbps, heartdisease)
# (chol _|_ sex, exang | restecg, thalach, fbs, age, trestbps)
# (chol _|_ sex, trestbps, exang | restecg, thalach, fbs, age, heartdisease)
# (chol _|_ sex, exang, age | restecg, thalach, fbs, trestbps, heartdisease)
# (chol _|_ fbs, sex, exang | restecg, thalach, age, trestbps, heartdisease)
# (chol _|_ thalach, sex, exang | restecg, fbs, age, trestbps, heartdisease)
# (chol _|_ sex, exang, restecg | thalach, fbs, age, trestbps, heartdisease)
# (chol _|_ age | sex, exang, restecg, thalach, fbs, trestbps)
# (chol _|_ trestbps, age | sex, exang, restecg, thalach, fbs, heartdisease)
# (chol _|_ fbs, trestbps | sex, exang, restecg, thalach, age, heartdisease)
# (chol _|_ fbs, age | sex, exang, restecg, thalach, trestbps, heartdisease)
# (chol _|_ thalach, trestbps | sex, exang, restecg, fbs, age, heartdisease)
# (chol _|_ thalach, age | sex, exang, restecg, fbs, trestbps, heartdisease)
# (chol _|_ thalach, fbs | sex, exang, restecg, age, trestbps, heartdisease)
# (chol _|_ trestbps, restecg | sex, exang, thalach, fbs, age, heartdisease)
# (chol _|_ restecg, age | sex, exang, thalach, fbs, trestbps, heartdisease)
# (chol _|_ fbs, restecg | sex, exang, thalach, age, trestbps, heartdisease)
# (chol _|_ thalach, restecg | sex, exang, fbs, age, trestbps, heartdisease)
# (chol _|_ exang | sex, restecg, thalach, fbs, age, trestbps)
# (chol _|_ trestbps, exang | sex, restecg, thalach, fbs, age, heartdisease)
# (chol _|_ exang, age | sex, restecg, thalach, fbs, trestbps, heartdisease)
# (chol _|_ fbs, exang | sex, restecg, thalach, age, trestbps, heartdisease)
# (chol _|_ thalach, exang | sex, restecg, fbs, age, trestbps, heartdisease)
# (chol _|_ exang, restecg | sex, thalach, fbs, age, trestbps, heartdisease)
# (chol _|_ sex | exang, restecg, thalach, fbs, age, trestbps)
# (chol _|_ sex, trestbps | exang, restecg, thalach, fbs, age, heartdisease)
# (chol _|_ sex, age | exang, restecg, thalach, fbs, trestbps, heartdisease)
# (chol _|_ fbs, sex | exang, restecg, thalach, age, trestbps, heartdisease)
# (chol _|_ thalach, sex | exang, restecg, fbs, age, trestbps, heartdisease)
# (chol _|_ sex, restecg | exang, thalach, fbs, age, trestbps, heartdisease)
# (chol _|_ sex, exang | restecg, thalach, fbs, age, trestbps, heartdisease)
# (chol _|_ trestbps | sex, exang, restecg, thalach, fbs, age, heartdisease)
# (chol _|_ age | sex, exang, restecg, thalach, fbs, trestbps, heartdisease)
# (chol _|_ fbs | sex, exang, restecg, thalach, age, trestbps, heartdisease)
# (chol _|_ thalach | sex, exang, restecg, fbs, age, trestbps, heartdisease)
# (chol _|_ restecg | sex, exang, thalach, fbs, age, trestbps, heartdisease)
# (chol _|_ exang | sex, restecg, thalach, fbs, age, trestbps, heartdisease)
# (chol _|_ sex | exang, restecg, thalach, fbs, age, trestbps, heartdisease)

# %%
#Inferencing with Bayesian Network 
from pgmpy.inference import VariableElimination 
HeartDisease_infer = VariableElimination(model)

# %%
# Computing the probability of bronc given smoke. 
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28} ) 
print(q['heartdisease']) 
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'chol': 100}) 
print(q['heartdisease'])
# Out:
# +----------------+---------------------+
# | heartdisease   |   phi(heartdisease) |
# +================+=====================+
# | heartdisease_0 |              0.6333 |
# +----------------+---------------------+
# | heartdisease_1 |              0.3667 |
# +----------------+---------------------+
# +----------------+---------------------+
# | heartdisease   |   phi(heartdisease) |
# +================+=====================+
# | heartdisease_0 |              1.0000 |
# +----------------+---------------------+
# | heartdisease_1 |              0.0000 |
# +----------------+---------------------+
# /usr/local/lib/python3.6/dist-packages/pgmpy/factors/discrete/DiscreteFactor.py:586: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi.values = phi.values[slice_]
# /usr/local/lib/python3.6/dist-packages/pgmpy/factors/discrete/DiscreteFactor.py:598: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi1.values = phi1.values[slice_]
